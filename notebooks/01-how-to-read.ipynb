# %%
import rioxarray as rxr
import matplotlib.pyplot as plt

from pathlib import Path

data_folder = Path('/home/simon/Documents/Data/Copernicus/DEM')

# %%
# list tiff files
tiff_files = list(data_folder.glob('*.tiff'))

# %%
tiff_files
# Out:
# [PosixPath('/home/simon/Documents/Data/Copernicus/DEM/Cluny-DEM-RAW.tiff')]

# %%
# open the first file
dem_raw = rxr.open_rasterio(tiff_files[0])

# %%
dem_raw
# Out:
# <xarray.DataArray (band: 1, y: 1693, x: 2500)> Size: 17MB
# [4232500 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 20kB 4.551 4.552 4.552 4.552 ... 4.767 4.767 4.767
#   * y            (y) float64 14kB 46.48 46.48 46.48 46.48 ... 46.38 46.38 46.38
#     spatial_ref  int64 8B 0
# Attributes:
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     AREA_OR_POINT:           Area
#     scale_factor:            1.0
#     add_offset:              0.0

# %%
dem_raw.rio.crs
# Out:
# CRS.from_epsg(4326)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

dem_raw.plot(ax=ax, cmap='terrain')
# zoom in and preserve aspect ratio
ax.set_aspect('equal')
plt.show()
