# %%
import rioxarray as rxr
import matplotlib.pyplot as plt

from pathlib import Path

data_folder = Path('/home/simon/Documents/Data/Copernicus/DEM')

# %%
# list tiff files
tiff_files = list(data_folder.glob('*.tiff'))

# %%
tiff_files
# Out:
# [PosixPath('/home/simon/Documents/Data/Copernicus/DEM/2024-09-29-00:00_2024-09-29-23:59_DEM_COPERNICUS_30_DEM_(Raw).tiff'),
#  PosixPath('/home/simon/Documents/Data/Copernicus/DEM/2024-09-29-00:00_2024-09-29-23:59_DEM_COPERNICUS_30_Topographic.tiff')]

# %%
# open the first file
dem_raw = rxr.open_rasterio(tiff_files[0])

# %%
dem_raw
# Out:
# <xarray.DataArray (band: 1, y: 2407, x: 2500)> Size: 24MB
# [6017500 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 8B 1
#   * x            (x) float64 20kB 4.686 4.686 4.686 4.686 ... 4.712 4.712 4.712
#   * y            (y) float64 19kB 46.2 46.2 46.2 46.2 ... 46.18 46.18 46.18
#     spatial_ref  int64 8B 0
# Attributes:
#     TIFFTAG_XRESOLUTION:     1
#     TIFFTAG_YRESOLUTION:     1
#     TIFFTAG_RESOLUTIONUNIT:  1 (unitless)
#     AREA_OR_POINT:           Area
#     scale_factor:            1.0
#     add_offset:              0.0

# %%
dem_raw.rio.crs
# Out:
# CRS.from_epsg(4326)

# %%
fig, ax = plt.subplots()

dem_raw.plot(ax=ax, cmap='terrain')

plt.show()
